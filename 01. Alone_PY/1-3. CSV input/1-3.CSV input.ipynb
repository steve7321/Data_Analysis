# %% [markdown]
# 마크다운 형식 정리
# #### 1. #갯수에 따라서 제목 형식
# ~~2. 물결 2개는 취소선~~
# **3. 곱하기 2개는 굵게**
# *4. 곱하기 1개는 이탤릭*
# >5.부등호는 들어쓰기
#
# * 6. 곱하기나 빼기 1개는 글머리 기호
# - 6. 곱하기나 빼기 1개는 글머리 기호
#
# 7. 링크
# [유튜브](www.youtube.com)
#
# 8. 수식: $ y = x \times z$

# %%
with open ('서울특별시교육청남산도서관 장서 대출목록 (2025년 02월).csv', encoding='EUC-KR') as f:
    print(f.readline())
    print(f.readline())
# Out:
# 번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,
#
# "1","쓰는 생활 - 기록으로 취향을 발견하고 나만의 길을 만드는 법","논디 김하영 지음","라이프앤페이지","2025","9791191462333","","","","","1","0","2025-02-28",

# %%
import pandas as pd
df = pd.read_csv('서울특별시교육청남산도서관 장서 대출목록 (2025년 02월).csv', encoding='EUC-KR', low_memory=False)

df.head()
# Out:
#    번호                                                도서명  \
# 0   1                 쓰는 생활 - 기록으로 취향을 발견하고 나만의 길을 만드는 법
# 1   2         9일간의 영혼 여행 :임사체험으로 알게 된 의식과 육체에 관한 새로운 진실
# 2   3             세상 끝 책방 이야기 - 모험과 사랑, 그리고 책으로 엮은 삶의 기록
# 3   4  (이토록 쉬운) RAG 시스템 구축을 위한 랭체인 실전 가이드 :LLM 기초부터 모...
# 4   5                이지 러스트 :실습하며 배우는 빠르고 안전한 코드 작성의 비결
#
#                      저자      출판사  발행년도           ISBN  세트 ISBN 부가기호    권  \
# 0             논디 김하영 지음  라이프앤페이지  2025  9791191462333      NaN  NaN  NaN
# 1    안케 에베르츠 지음 ;추미란 옮김       샨티  2025  9791192604329      NaN    0  NaN
# 2       루스 쇼 지음, 신정은 옮김     그림나무  2025  9791199055605      NaN  NaN  NaN
# 3                윤성재 지음    루비페이퍼  2024  9791193083239      NaN  NaN  NaN
# 4  데이브 매클라우드 지음 ;이지호 옮김    한빛미디어  2025  9791169213462      NaN    9  NaN
#
#     주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0      NaN     1     0  2025-02-28          NaN
# 1      187     1     0  2025-02-28          NaN
# ...

# %%
df.to_csv('ns_202502.csv')

with open('ns_202502.csv', encoding='UTF-8') as f:
    for i in range(3):
        print (f.readline(), end='')
# Out:
# ,번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,Unnamed: 13
# 0,1,쓰는 생활 - 기록으로 취향을 발견하고 나만의 길을 만드는 법,논디 김하영 지음,라이프앤페이지,2025,9791191462333,,,,,1,0,2025-02-28,
# 1,2,9일간의 영혼 여행 :임사체험으로 알게 된 의식과 육체에 관한 새로운 진실 ,안케 에베르츠 지음 ;추미란 옮김,샨티,2025,9791192604329,,0,,187,1,0,2025-02-28,

# %%
ns_df=pd.read_csv('ns_202502.csv', index_col=0, low_memory=False)
ns_df.head()
# Out:
#    번호                                                도서명  \
# 0   1                 쓰는 생활 - 기록으로 취향을 발견하고 나만의 길을 만드는 법
# 1   2         9일간의 영혼 여행 :임사체험으로 알게 된 의식과 육체에 관한 새로운 진실
# 2   3             세상 끝 책방 이야기 - 모험과 사랑, 그리고 책으로 엮은 삶의 기록
# 3   4  (이토록 쉬운) RAG 시스템 구축을 위한 랭체인 실전 가이드 :LLM 기초부터 모...
# 4   5                이지 러스트 :실습하며 배우는 빠르고 안전한 코드 작성의 비결
#
#                      저자      출판사  발행년도           ISBN  세트 ISBN 부가기호    권  \
# 0             논디 김하영 지음  라이프앤페이지  2025  9791191462333      NaN  NaN  NaN
# 1    안케 에베르츠 지음 ;추미란 옮김       샨티  2025  9791192604329      NaN    0  NaN
# 2       루스 쇼 지음, 신정은 옮김     그림나무  2025  9791199055605      NaN  NaN  NaN
# 3                윤성재 지음    루비페이퍼  2024  9791193083239      NaN  NaN  NaN
# 4  데이브 매클라우드 지음 ;이지호 옮김    한빛미디어  2025  9791169213462      NaN    9  NaN
#
#     주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0      NaN     1     0  2025-02-28          NaN
# 1      187     1     0  2025-02-28          NaN
# ...

# %%
# !pip install xlsxwriter
ns_df.to_excel('ns_202502.xlsx', index=False, engine='xlsxwriter')
